# %% [markdown]
# # EDS 213: World Bank & Energy Data Cleaning
#
# Author: Leilanie Rubinstein
#
# Date: May 15, 2025
#
# *Questions:*
#
# 1. **Which countries in Africa will be most affected by trade stagnation (ie highest cost of electricity per unit)?**
# 2. **Is there a relationship between fuel consumption/production type and degree of trade stagnation?**

# %%
# Load libraries
import os
import re

import matplotlib.pyplot as plt
import numpy as np
import openpyxl
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Import World Bank IDA data
#
# https://databank.worldbank.org/source/ida-results-measurement-system,-tier-i-database-%E2%80%93-wdi/Series/EG.ELC.ACCS.ZS

# %%
ida_data = pd.read_csv("data/116b125a-8cee-4efc-afef-1b6e33d96d3b_Data.csv")
ida_data
# Out:
#                                            Country Name Country Code  \
# 0                                       001. Benin_SBEE     BEN_SBEE
# 1                                       001. Benin_SBEE     BEN_SBEE
# 2                                       001. Benin_SBEE     BEN_SBEE
# 3                                       001. Benin_SBEE     BEN_SBEE
# 4                                       001. Benin_SBEE     BEN_SBEE
# ...                                                 ...          ...
# 3120                                                NaN          NaN
# 3121                                                NaN          NaN
# 3122                                                NaN          NaN
# 3123  Data from database: Africa Infrastructure: Ele...          NaN
# 3124                           Last Updated: 12/09/2009          NaN
#
#                                             Series Name Series Code  \
# 0     Average residential connection charge (LCU/con...    AFELE118
# 1     Average residential connection charge (USD/con...    AFELE119
# 2     Collection rate, implicit: ratio of unit reven...    AFELE154
# 3     Collection rate, reported by utility (% of bil...    AFELE126
# 4     Cost of electricity per unit, capital, histori...    AFELE111
# ...                                                 ...         ...
# 3120                                                NaN         NaN
# 3121                                                NaN         NaN
# 3122                                                NaN         NaN
# 3123                                                NaN         NaN
# 3124                                                NaN         NaN
#
#      1994 [YR1994] 1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998]  \
# 0               ..            ..            ..            ..            ..
# 1               ..            ..            ..            ..            ..
# 2               ..            ..            ..            ..            ..
# 3               ..            ..            ..            ..            ..
# 4               ..            ..            ..            ..            ..
# ...            ...           ...           ...           ...           ...
# 3120           NaN           NaN           NaN           NaN           NaN
# 3121           NaN           NaN           NaN           NaN           NaN
# 3122           NaN           NaN           NaN           NaN           NaN
# 3123           NaN           NaN           NaN           NaN           NaN
# 3124           NaN           NaN           NaN           NaN           NaN
#
#      1999 [YR1999]  ... 2004 [YR2004]     2005 [YR2005] 2006 [YR2006]  \
# 0               ..  ...            ..                ..            ..
# 1               ..  ...            ..                ..            ..
# 2               ..  ...            ..               100            ..
# 3               ..  ...            ..                ..            ..
# 4               ..  ...            ..  11.5822823192855            ..
# ...            ...  ...           ...               ...           ...
# 3120           NaN  ...           NaN               NaN           NaN
# 3121           NaN  ...           NaN               NaN           NaN
# 3122           NaN  ...           NaN               NaN           NaN
# 3123           NaN  ...           NaN               NaN           NaN
# 3124           NaN  ...           NaN               NaN           NaN
#
#      2007 [YR2007] 2008 [YR2008] 2009 [YR2009]     LAV [YR20080]  \
# 0               ..            ..            ..                ..
# 1               ..            ..            ..                ..
# 2               ..            ..            ..               100
# 3               ..            ..            ..                ..
# 4               ..            ..            ..  11.5822823192855
# ...            ...           ...           ...               ...
# 3120           NaN           NaN           NaN               NaN
# 3121           NaN           NaN           NaN               NaN
# 3122           NaN           NaN           NaN               NaN
# 3123           NaN           NaN           NaN               NaN
# 3124           NaN           NaN           NaN               NaN
#
#      MRV [YR19950] MRV1 [YR20006]    MRV2 [YR20081]
# 0               ..             ..                ..
# 1               ..             ..                ..
# 2               ..             ..               100
# 3               ..             ..                ..
# 4               ..             ..  11.5822823192855
# ...            ...            ...               ...
# 3120           NaN            NaN               NaN
# 3121           NaN            NaN               NaN
# 3122           NaN            NaN               NaN
# 3123           NaN            NaN               NaN
# 3124           NaN            NaN               NaN
#
# [3125 rows x 24 columns]

# %%
# Extract series names
ida_data["Series Name"].unique()
# Out:
# array(['Average residential connection charge (LCU/connection)',
#        'Average residential connection charge (USD/connection)',
#        'Collection rate, implicit: ratio of unit revenue collected to tariff (%)',
#        'Collection rate, reported by utility (% of billing)',
#        'Cost of electricity per unit, capital, historical (US cents/kWh)',
#        'Cost of electricity per unit, LRMC, optimal trade scenario (US cents/kWh)',
#        'Cost of electricity per unit, LRMC, trade stagnation scenario (US cents/kWh)',
#        'Cost of electricity per unit, operating, historical (US cents/kWh)',
#        'Cost of electricity per unit, total, historical (US cents/kWh)',
#        'Cost recovery ratio, historical (%)',
#        'Cost recovery ratio, LRMC (%)',
#        'Customers, all voltage levels (number)',
#        'Customers, high and medium voltage (% of total number of customers)',
#        'Customers, high and medium voltage (number)',
#        'Customers, high voltage (number)',
#        'Customers, low voltage (number)',
#        'Customers, medium voltage (number)',
#        'Effective tariff, consumption 100kWh/month (US cents/kWh)',
#        'Effective tariff, consumption 150kWh/month (US cents/kWh)',
#        'Effective tariff, consumption 200kWh/month (US cents/kWh)',
#        'Effective tariff, consumption 300kWh/month (US cents/kWh)',
#        'Effective tariff, consumption 400kWh/month (US cents/kWh)',
#        'Effective tariff, consumption 500kWh/month (US cents/kWh)',
#        'Effective tariff, consumption 50kWh/month (US cents/kWh)',
#        'Electricity billed per commercial/medium voltage customer (kWh/customer)',
#        'Electricity billed per industrial/high voltage customer (kWh/customer)',
#        'Electricity billed per residential/low voltage customer (kWh/customer)',
#        'Electricity billed to commercial/medium voltage customers (GWh/year)',
#        'Electricity billed to industrial/high voltage customers (GWh/year)',
#        'Electricity billed to residential/low voltage customers (GWh/year)',
#        'Electricity connections per employee (number)',
#        'Electrification rate (% of popul. with electricity connection in utility service area)',
#        'Hidden costs due to under-collection (% of GDP)',
#        'Hidden costs due to under-collection (% of revenue)',
#        'Hidden costs due to under-collection (% of total hidden costs)',
#        'Labor costs (% of operational costs)', 'Labor costs (LCU/year)',
#        'Labor costs (USD/year)', 'Operational costs (LCU/year)',
#        'Operational costs (USD/year)',
#        'Prepayment meters (% of all meters)',
#        'Residential/low voltage customers with operating meters (% of residential customers)',
#        'Revenue (LCU/year)', 'Revenue (USD/year)',
#        'Revenue from commercial/medium voltage customers (LCU/year)',
#        'Revenue from commercial/medium voltage customers (USD/year)',
#        'Revenue from customers of all voltage levels (USD/year)',
#        'Revenue from high voltage+medium voltage customers (% of total revenue)',
#        'Revenue from high voltage+medium voltage customers (USD/year)',
#        'Revenue from industrial/high voltage customers (LCU/year)',
#        'Revenue from industrial/high voltage customers (USD/year)',
#        'Revenue from residential/low voltage customers (LCU/year)',
#        'Revenue from residential/low voltage customers (USD/year)',
#        'Revenue per high voltage customer, annual, electricity (USD/customer/year)',
#        'Revenue per low voltage customer, annual, electricity (USD/customer/year)',
#        'Revenue per medium voltage customer, annual, electricity (USD/customer/year)',
#        'Revenue per unit, electricity (US cents/kWh)',
#        'System losses (% of generation)',
#        'Unit operational expenses, annual (LCU/kWh)',
#        'Unit operational expenses, annual (US cents/kWh)', nan],
#       dtype=object)

# %% [markdown]
# #### Variables of interest:
#
# - "Cost of electricity per unit, LRMC, trade stagnation scenario (US cents/kWh)"
# - "Cost of electricity per unit, LRMC, optimal trade scenario (US cents/kWh)"
# - "Cost of electricity per unit, total, historical (US cents/kWh)"
#
# "LRMC" = Long Run Marginal Cost

# %%
# Define the scenarios and their names
scenarios = {
    "trade_stag": "Cost of electricity per unit, LRMC, trade stagnation scenario (US cents/kWh)",
    "trade_optim": "Cost of electricity per unit, LRMC, optimal trade scenario (US cents/kWh)",
    "tot_historical": "Cost of electricity per unit, total, historical (US cents/kWh)",
}

# Define columns to keep
column_mapping = {
    "Country Name": "utility_code",
    "LAV [YR20080]": "lav_2008",
    "MRV2 [YR20081]": "mrv2_2008",
}

# Extract all scenarios in one loop with renamed columns
results = {}
for key, series_name in scenarios.items():
    # Extract the data for the current scenario
    df = ida_data[ida_data["Series Name"] == series_name].filter(
        items=list(column_mapping.keys()), axis=1
    )

    # Replace ".." with NaN
    df = df.replace("..", float("nan"))

    # Rename the columns
    df = df.rename(columns=column_mapping)

    # Convert numeric columns to float
    for col in ["lav_2008", "mrv2_2008"]:
        df[col] = pd.to_numeric(df[col], errors="coerce")

    # Extract country names from utility_code
    df["country_name"] = df["utility_code"].apply(
        lambda x: re.sub(r"^\d+\.\s", "", x).split("_")[0]
        if isinstance(x, str)
        else None
    )

    # Drop rows where all values are NA
    df = df.dropna(how="all")

    # Reset index
    df = df.reset_index(drop=True)

    # Store in results dictionary
    results[key] = df

# Access scenario by name
trade_stag = results["trade_stag"]
trade_optim = results["trade_optim"]
tot_historical = results["tot_historical"]
tot_historical
# Out:
#                                          utility_code   lav_2008  mrv2_2008  \
# 0                                     001. Benin_SBEE  13.725913  13.725913
# 1                           002. Burkina Faso_Sonabel  23.557524  23.557524
# 2                             003. Cameroon_AES SONEL  13.979235  13.979235
# 3                             004. Cape Verde_Electra  23.342074  23.342074
# 4                                      005. Chad_STEE  83.604324  83.604324
# 5                          006. Congo, Dem. Rep._SNEL   6.754000   6.754000
# 6                                   007. CongoRep_SNE   0.120000   0.120000
# 7                              008. Cote d'Ivoire_CIE        NaN        NaN
# 8                                 009. Ethiopia_EEPCO   8.814480   8.814480
# 9                                      010. Ghana_ECG  13.244049  13.244049
# 10                                     011. Ghana_VRA        NaN        NaN
# 11                                  012. Kenya_KENGEN        NaN        NaN
# 12                                    013. Kenya_KPLC  13.730788  13.730788
# 13                                   014. Lesotho_LEC  11.485223  11.485223
# 14                             015. Madagascar_JIRAMA  16.447225  16.447225
# 15                                  016. Malawi_Escom  10.318746  10.318746
# 16                                      017. Mali_EDM        NaN        NaN
# 17                                018. Mozambique_EDM   9.489485   9.489485
# 18                              019. Namibia_Nampower  18.785353  18.785353
# 19                                 020. Namibia_NORED        NaN        NaN
# 20                                 021. Niger_NIGELEC  43.200584  43.200584
# 21                                  022. Nigeria_PHCN   7.547659   7.547659
# 22                             023. Rwanda_Electrogaz  38.246800  38.246800
# 23                               024. Senegal_Senelec  23.870667  23.870667
# 24                         025. South Africa_Capetown   5.725174   5.725174
# 25                            026. South Africa_ESKOM        NaN        NaN
# 26                          027. South Africa_Tshwane        NaN        NaN
# 27                                     028. Sudan_NEC        NaN        NaN
# 28                              029. Tanzania_TANESCO  16.024620  16.024620
# 29                                  030. Uganda_UEDCL  12.301698  12.301698
# 30                                  031. Uganda_UEGCL        NaN        NaN
# 31                                  032. Uganda_UETCL        NaN        NaN
# 32                                  033. Zambia_ZESCO   7.367536   7.367536
# 33                           034. Low Income, Fragile        NaN  27.976441
# 34                       035. Low Income, Non-Fragile        NaN  18.690198
# 35                                 036. middle Income        NaN  28.124688
# 36                                 037. Resource Rich        NaN  14.834456
# 37                                           038. SSA        NaN  19.161962
# 38                                         039. CEMAC        NaN  48.791779
# 39                                        040. COMESA        NaN  14.247659
# 40                                           041. EAC        NaN  20.075976
# 41                                        042. ECOWAS        NaN  21.212639
# 42                                          043. SADC        NaN  11.377485
# 43                     044. Central Africa Power Pool        NaN  48.791779
# 44                     045. Eastern Africa Power Pool        NaN  15.978731
# 45                    046. Southern Africa Power Pool        NaN  11.377485
# 46                     047. Western Africa Power Pool        NaN  21.212639
# 47  048. Countries with predominantly hydro genera...        NaN  13.887847
# 48  049. Countries with installed capacity below 2...        NaN  35.600820
# 49  050. Countries with installed capacity above 1...        NaN   9.122670
# 50  051. Countries with installed capacity 200 MW ...        NaN  16.011061
# 51  052. Countries with predominantly thermal gene...        NaN  26.780127
#
#                                          country_name
# 0                                               Benin
# 1                                        Burkina Faso
# 2                                            Cameroon
# 3                                          Cape Verde
# 4                                                Chad
# 5                                    Congo, Dem. Rep.
# 6                                            CongoRep
# 7                                       Cote d'Ivoire
# 8                                            Ethiopia
# 9                                               Ghana
# 10                                              Ghana
# 11                                              Kenya
# 12                                              Kenya
# 13                                            Lesotho
# 14                                         Madagascar
# 15                                             Malawi
# 16                                               Mali
# 17                                         Mozambique
# 18                                            Namibia
# 19                                            Namibia
# 20                                              Niger
# 21                                            Nigeria
# 22                                             Rwanda
# 23                                            Senegal
# 24                                       South Africa
# 25                                       South Africa
# 26                                       South Africa
# 27                                              Sudan
# 28                                           Tanzania
# 29                                             Uganda
# 30                                             Uganda
# 31                                             Uganda
# 32                                             Zambia
# 33                                Low Income, Fragile
# 34                            Low Income, Non-Fragile
# 35                                      middle Income
# 36                                      Resource Rich
# 37                                                SSA
# 38                                              CEMAC
# 39                                             COMESA
# 40                                                EAC
# 41                                             ECOWAS
# 42                                               SADC
# 43                          Central Africa Power Pool
# 44                          Eastern Africa Power Pool
# 45                         Southern Africa Power Pool
# 46                          Western Africa Power Pool
# 47      Countries with predominantly hydro generation
# 48     Countries with installed capacity below 200 MW
# 49   Countries with installed capacity above 1,000 MW
# 50  Countries with installed capacity 200 MW to 1,...
# 51    Countries with predominantly thermal generation

# %% [markdown]
# #### Write to CSV

# %%
trade_stag.to_csv(os.path.join("energy_data", "ida_trade_stag.csv"))
trade_optim.to_csv(os.path.join("energy_data", "ida_trade_optim.csv"))
tot_historical.to_csv(os.path.join("energy_data", "ida_tot_historical.csv"))

# %% [markdown]
# ### Import Energy Institute World Energy Data
#
# https://www.energyinst.org/statistical-review/resources-and-data-downloads

# %%
energy_inst = pd.read_excel(
    "data/Statistical Review of World Energy Data.xlsx", sheet_name=None
)

# %%
print(energy_inst.keys())

# Extract the data from the first sheet
energy_data_0 = energy_inst["Contents"]
energy_data_0.values
# Out:
# dict_keys(['Contents', 'Primary energy cons - EJ', 'PE Cons by fuel EJ', 'PE cons per capita GJ', 'Carbon Dioxide from Energy', 'CO2 From Flaring', 'Natural Gas Flaring', 'CO2-Process Emissions, Methane', 'CO2e Emissions ', 'CCUS Capture Capacity', 'Carbon Prices', 'Oil - Proved reserves', 'Oil - Proved reserves history', 'Oil Production - barrels', 'Oil Production - tonnes', 'Crude+cond production - barrels', 'NGLs production - barrels', 'Liquids Consumption - barrels', 'Oil Consumption - barrels', 'Oil Consumption - Tonnes', 'Oil Consumption - EJ', 'Oil - Regional Consumption', 'Spot crude prices', 'Oil crude prices since 1861', 'Oil refinery - throughput', 'Oil refinery - capacity', 'Oil - Regional refining margins', 'Oil trade movements', 'Oil - Inter-area movements', 'Oil - Trade movements in 22-23', 'Gas - Proved reserves', 'Gas - Proved reserves history ', 'Gas Production - Bcm', 'Gas Production - Bcf', 'Gas Production - EJ', 'Gas Consumption - Bcm', 'Gas Consumption - Bcf', 'Gas Consumption - EJ', 'Gas - H2 Production Capacity', 'Gas Prices ', 'Gas - Trade movements', 'Gas - LNG imports bcm', 'Gas - LNG exports bcm', 'Gas trade - LNG', 'Gas trade - pipeline', 'Coal - Reserves', 'Coal Production - mt', 'Coal Production - EJ', 'Coal Consumption - EJ', 'Coal &amp; Uranium - Prices', 'Coal - Trade movements', 'Coal trade movements 2023', 'Nuclear Generation - TWh', 'Nuclear Consumption - EJ', 'Hydro Generation - TWh', 'Hydro Consumption - EJ', 'Renewables Consumption -EJ', 'Renewable Power (inc hydro) -EJ', 'Ren power (excl hydro) - EJ', 'Renewable Power (inc hydro)-TWh', 'Ren power (excl hydro) - TWh', 'Renewables Generation by Source', 'Solar Generation - TWh', 'Solar Consumption - EJ', 'Solar Installed Capacity', 'Wind Generation - TWh', 'Wind Consumption - EJ', 'Wind Installed Capacity', 'Wind and Solar Technology Types', 'Geo Biomass Other - TWh', 'Geo Biomass Other - EJ', 'Biofuels production - kboed', 'Biofuels production - PJ', 'Biofuels Consumption - kboed', 'Biofuels consumption - PJ', 'Electricity Generation - TWh', 'Elec generation by fuel', 'Oil inputs - Elec generation ', 'Gas inputs - Elec generation', 'Coal inputs - Elec generation ', 'Other inputs - Elec generation', 'Grid Scale BESS Capacity', 'Cobalt P-R', 'Lithium P-R', 'Natural Graphite P-R', 'Rare Earth metals P-R', 'Copper P-R', 'Platinum Group Metals P-R', 'Manganese P-R', 'Nickel P-R', 'Mineral Commodity Prices', 'Approximate conversion factors', 'Definitions', 'Methodology'])
# array([['2024 Energy Institute Statistical Review of World Energy'],
#        [nan],
#        ['This workbook contains information presented in the 2024'],
#        ['Energy Institute Statistical Review of World Energy, which can be found on the'],
#        ['internet at:'],
#        [nan],
#        ['EI Statistical Review of World Energy'],
#        [nan],
#        ['Please use the contents or the tabs at the bottom to navigate between the tables.'],
#        [nan],
#        ['Primary Energy: Consumption - Exajoules (from 1965)'],
#        ['Primary Energy: Consumption by fuel type - Exajoules (2022 and 2023)'],
#        ['Primary Energy: Consumption per capita - Gigajoule per capita (from 1965)'],
#        [nan],
#        ['Carbon: Carbon Dioxide Emissions from Energy (from 1965)'],
#        ['Carbon: Carbon Dioxide Emissions from Flaring (from 1975)'],
#        ['Natural Gas Flaring'],
#        ['Carbon: Carbon Dioxide Equivalent Emissions from Methane and Process Emissions (from 1990)'],
#        ['Carbon: Carbon Dioxide Equivalent Emissions from Energy, Process Emissions, Methane, and Flaring (from 1990)'],
#        ['Carbon: Carbon Capture, Usage, and Storage (CCUS) (from 2013)'],
#        ['Carbon: Carbon Prices'],
#        [nan],
#        ['Oil: Proved reserves'],
#        ['Oil: Proved reserves - Barrels (from 1980)'],
#        ['Oil: Production - Barrels (from 1965)'],
#        ['Oil: Production - Tonnes (from 1965)'],
#        ['Oil: Crude oil and condensate production - Barrels (from 2000)'],
#        ['Oil: Natural Gas Liquids production - Barrels (from 2000)'],
#        ['Oil: Total liquids consumption - Barrels (from 1965)'],
#        ['Oil: Consumption - Barrels (from 1965)'],
#        ['Oil: Consumption - Tonnes (from 1965)'],
#        ['Oil: Consumption - Exajoules (from 1965)'],
#        ['Oil: Regional consumption - by product - Barrels (from 1965)'],
#        ['Oil: Spot crude prices '],
#        ['Oil: Crude prices (from 1861)'],
#        ['Oil: Refinery throughput (from 1980)'],
#        ['Oil: Refining capacity (from 1965)'],
#        ['Oil: Regional refining margins (from 2000)'],
#        ['Oil: Trade movements (from 1980)'],
#        ['Oil: Inter-area movements (for 2023)'],
#        ['Oil: Trade 2022 and 2023'],
#        [nan],
#        ['Gas: Proved reserves'],
#        ['Gas: Proved reserves - Bcm (from 1980)'],
#        ['Gas: Production - Bcm (from 1970)'],
#        ['Gas: Production - Bcf (from 1970)'],
#        ['Gas: Production - Exajoules (from 1970)'],
#        ['Gas: Consumption - Bcm (from 1965)'],
#        ['Gas: Consumption - Bcf (from 1965)'],
#        ['Gas: Consumption - Exajoules (from 1965)'],
#        ['Gas: Hydrogen Production Capacity (from 2000)'],
#        ['Gas: Prices '],
#        ['Gas: Inter-regional trade (from 2000)'],
#        ['Gas: LNG imports (from 2000)'],
#        ['Gas: LNG exports (from 2000)'],
#        ['Gas: Trade movements LNG (for 2023)'],
#        ['Gas: Trade movements pipeline (for 2023)'],
#        [nan],
#        ['Coal: Reserves'],
#        ['Coal: Production - Tonnes (from 1981)'],
#        ['Coal: Production - Exajoules (from 1981)'],
#        ['Coal: Consumption - Exajoules (from 1965)'],
#        ['Coal: Mined energy resource prices (from 1987)'],
#        ['Coal: Trade movements (from 2000)'],
#        ['Coal: Inter-area movements (for 2023)'],
#        [nan],
#        ['Nuclear Energy - Generation - TWh (from 1965)'],
#        ['Nuclear Energy - Consumption - Exajoules (from 1965)'],
#        [nan],
#        ['Hydroelectricity - Generation - TWh (from 1965)'],
#        ['Hydroelectricity - Consumption - Exajoules (from 1965)'],
#        [nan],
#        ['Renewables - Combined renewable electricity and biofuels primary energy input consumption - Exajoules (from 1965)'],
#        ['Renewables - Renewable Power Primary Energy Input Consumption (inc hydro)- Exajoules (from 1965)'],
#        ['Renewables - Renewable Power Primary Energy Input Consumption (exc hydro) - Exajoules (from 1965)'],
#        ['Renewables - Renewable Power Primary Energy Input Consumption (inc hydro) - TWh (from 1965)'],
#        ['Renewables - Renewable Power Primary Energy Input Consumption (exc hydro) - TWh (from 1965)'],
#        ['Renewables - Generation by source - TWh (2022 and 2023)'],
#        ['Renewables - Solar generation - TWh (from 1965)'],
#        ['Renewables - Solar consumption - Exajoules (from 1965)'],
#        ['Renewable Energy - Solar (Installed capacity)'],
#        ['Renewables - Wind generation - TWh (from 1965)'],
#        ['Renewables - Wind consumption - Exajoules (from 1965)'],
#        ['Renewable Energy - Wind  (Installed capacity)'],
#        ['Renewable Energy - Solar and Wind Installed capacity by type (2022 and 2023)'],
#        ['Renewables - Geothermal, Biomass and Other generation - TWh  (from 1965)'],
#        ['Renewables - Geothermal, Biomass and Other - Exajoules (from 1965)'],
#        ['Renewables - Biofuels production - Kboe/d (from 1990)'],
#        ['Renewables - Biofuels production - Petajoules (from 1990)'],
#        ['Renewables - Biofuels consumption - Kboe/d (from 1990)'],
#        ['Renewables - Biofuels consumption - Petajoules (from 1990)'],
#        [nan],
#        ['Electricity generation - TWh (from 1985)'],
#        ['Electricity generation by fuel - TWh (2022 and 2023)'],
#        ['Electricity generation from oil -TWh (from 1985)'],
#        ['Electricity generation from gas - TWh (from 1985)'],
#        ['Electricity generation from coal - TWh (from 1985)'],
#        ['Electricity generation from other - TWh (from 1985)'],
#        ['Electricity - Grid-Scale Battery Energy Storage Systems (BESS) (from 2013)'],
#        [nan],
#        ['Key materials - Cobalt Production - Reserves (from 1995)'],
#        ['Key materials - Lithium Production - Reserves (from 1995)'],
#        ['Key materials - Graphite Production - Reserves (from 1995)'],
#        ['Key materials - Rare Earth Production - Reserves (from 1995)'],
#        ['Key materials - Copper Production - Reserves (from 1995)'],
#        ['Key materials - Platinum Group Metals Production - Reserves (from 1995)'],
#        ['Key materials - Manganese Production - Reserves (from 1995)'],
#        ['Key materials - Nickel Production - Reserves (from 1995)'],
#        ['Key materials - Mineral Commodity Prices'],
#        [nan],
#        ['Approximate conversion factors'],
#        [nan],
#        ['Definitions'],
#        [nan],
#        ['Methodology']], dtype=object)

# %%
# Oil Consumption: Barrels (from 1965), in thousand barrels daily
ei_oil_consumption = energy_inst["Oil Consumption - barrels"]

# Set the second row as column headers
ei_oil_consumption.columns = ei_oil_consumption.iloc[1]

# Find duplicate columns
duplicated_cols = ei_oil_consumption.columns[ei_oil_consumption.columns.duplicated()]
print("Duplicated columns:", duplicated_cols)

# Keep the second "2023" column and drop the first one
cols_to_keep = ~ei_oil_consumption.columns.duplicated(keep="first")
ei_oil_consumption = ei_oil_consumption.iloc[:, cols_to_keep]

column_mapping = {
    "Thousand barrels daily": "country_name",
    "2013-23": "growth_rate_per_annum_2013_2023",
}

new_columns = []
for col in ei_oil_consumption.columns:
    # Convert to string
    col_str = str(col)

    # Check if column is in custom mapping
    if col_str in column_mapping:
        new_columns.append(column_mapping[col_str])
    else:
        # Check if the column name can be converted to float and looks like a year
        try:
            if float(col_str) >= 1900 and float(col_str) <= 2100:
                # If it's a year column like '2000.0', convert to '2000'
                new_columns.append(str(int(float(col_str))))
            else:
                # For other numeric columns, convert to snake_case
                new_columns.append(col_str.lower().replace(" ", "_"))
        except (ValueError, TypeError):
            # For non-numeric columns, convert to snake_case
            new_columns.append(col_str.lower().replace(" ", "_").replace("-", "_"))

# Apply the new column names
ei_oil_consumption.columns = new_columns

# Clean up the data
ei_oil_consumption = ei_oil_consumption.replace("..", float("nan"))

# Convert numeric columns to float
numeric_cols = [col for col in new_columns if col != "country_name"]
for col in numeric_cols:
    ei_oil_consumption[col] = pd.to_numeric(ei_oil_consumption[col], errors="coerce")

# Drop rows where all values are NA
ei_oil_consumption = ei_oil_consumption.dropna(how="all")

# Remove the first two rows and cut off at row 104
ei_oil_consumption = ei_oil_consumption.iloc[2:104].copy()

# Reset index after dropping rows
ei_oil_consumption = ei_oil_consumption.reset_index(drop=True)
ei_oil_consumption
# Out:
# Duplicated columns: Index([2023, 2023], dtype='object', name=1)
#                           country_name          1965          1966  \
# 0                               Mexico    315.871088    333.048484
# 1                                   US  11512.436000  12084.373000
# 2                  Total North America  12936.423389  13584.890278
# 3                            Argentina    455.874013    471.137797
# 4                               Brazil    305.673808    334.602575
# ..                                 ...           ...           ...
# 97                  Total Asia Pacific   3299.278338   3859.759121
# 98                         Total World  30884.728725  33315.007646
# 99                      of which: OECD  23245.355770  25088.253332
# 100                           Non-OECD   7639.372955   8226.754314
# 101                   European Union #   6333.132566   6992.880434
#
#              1967          1968          1969          1970          1971  \
# 0      357.305957    386.144762    410.021906    440.735987    467.284852
# 1    12560.345000  13392.866000  14136.795000  14697.186000  15212.493000
# 2    14163.208026  15101.168112  15927.007234  16609.501741  17191.906098
# 3      484.114060    493.543629    516.739504    473.158155    505.365589
# 4      344.540164    412.432377    456.564904    520.116187    587.672022
# ..            ...           ...           ...           ...           ...
# 97    4409.428772   4990.671465   5932.875182   6962.977340   7631.729011
# 98   35641.940695  38529.930312  41968.402228  45676.477412  48180.544118
# 99   26859.695981  29127.938524  31855.624566  34598.225256  36204.385045
# 100   8782.244714   9401.991788  10112.777662  11078.252156  11976.159073
# 101   7605.968652   8387.325555   9452.673210  10565.105165  11151.068566
#
#              1972          1973  ...          2015          2016  \
# 0      523.353166    564.177805  ...   2037.825767   2085.123858
# 1    16366.984000  17307.679000  ...  18499.208493  18592.694872
# 2    18479.246401  19626.742450  ...  22967.842081  23116.989463
# 3      501.638934    507.347836  ...    695.411056    677.298262
# 4      667.630165    807.227492  ...   2583.140145   2453.466355
# ..            ...           ...  ...           ...           ...
# 97    8355.932064   9432.369591  ...  32159.586887  33349.487596
# 98   51869.362347  56064.206201  ...  92766.907605  94680.495719
# 99   38898.854933  41852.228585  ...  45295.544370  45848.664864
# 100  12970.507414  14211.977616  ...  47471.363235  48831.830855
# 101  11940.846906  12901.038750  ...  10981.612769  11135.053302
#
#              2017          2018          2019          2020          2021  \
# 0     2038.034090   1918.176846   1817.563961   1602.036162   1769.775415
# 1    18845.188693  19416.588252  19423.625252  17183.319352  18784.703315
# 2    23290.926148  23811.158366  23727.191640  20906.534778  22773.508279
# 3      671.546032    644.856482    567.253109    504.314310    612.685196
# 4     2485.123066   2367.524169   2361.034320   2218.497517   2394.197835
# ..            ...           ...           ...           ...           ...
# 97   34615.403130  35507.648445  36184.117863  34179.876864  35249.882214
# 98   96723.144944  97963.867782  98222.909413  89447.586736  94731.671676
# 99   46456.282788  46759.217162  46474.785138  40886.532788  43807.161193
# 100  50266.862156  51204.650621  51748.124275  48561.053948  50924.510483
# 101  11438.628967  11355.587166  11317.922949   9855.141726  10390.427476
#
#              2022           2023  growth_rate_per_annum_2013_2023
# 0     1931.355326    1961.617607                        -0.009963
# 1    18862.210266   18983.557337                         0.005379
# 2    23105.582600   23296.337729                         0.003158
# 3      723.458195     689.692218                         0.000639
# 4     2512.240799    2566.948105                        -0.003217
# ..            ...            ...                              ...
# 97   36110.480305   38061.126492                         0.023253
# 98   97683.275140  100220.603019                         0.010701
# 99   44769.860359   44731.353647                        -0.000652
# 100  52913.414781   55489.249372                         0.020999
# 101  10686.508716   10488.011057                        -0.004400
#
# [102 rows x 61 columns]

# %%
# Crude oil & condensate: Production (from 2000), in thousand barrels daily
ei_crude_cond_production = energy_inst["Crude+cond production - barrels"]

# Set the second row as column headers
ei_crude_cond_production.columns = ei_crude_cond_production.iloc[1]

# Find duplicate columns
duplicated_cols = ei_crude_cond_production.columns[
    ei_crude_cond_production.columns.duplicated()
]
print("Duplicated columns:", duplicated_cols)

# Keep the second "2023" column and drop the first one
cols_to_keep = ~ei_crude_cond_production.columns.duplicated(keep="first")
ei_crude_cond_production = ei_crude_cond_production.iloc[:, cols_to_keep]

column_mapping = {
    "Thousand barrels daily": "country_name",
    "2013-23": "growth_rate_per_annum_2013_2023",
}

new_columns = []
for col in ei_crude_cond_production.columns:
    # Convert to string
    col_str = str(col)

    # Check if column is in custom mapping
    if col_str in column_mapping:
        new_columns.append(column_mapping[col_str])
    else:
        # Check if the column name can be converted to float and looks like a year
        try:
            if float(col_str) >= 1900 and float(col_str) <= 2100:
                # If it's a year column like '2000.0', convert to '2000'
                new_columns.append(str(int(float(col_str))))
            else:
                # For other numeric columns, convert to snake_case
                new_columns.append(col_str.lower().replace(" ", "_"))
        except (ValueError, TypeError):
            # For non-numeric columns, convert to snake_case
            new_columns.append(col_str.lower().replace(" ", "_").replace("-", "_"))

# Apply the new column names
ei_crude_cond_production.columns = new_columns

# Clean up the data
ei_crude_cond_production = ei_crude_cond_production.replace("..", float("nan"))

# Convert numeric columns to float
numeric_cols = [col for col in new_columns if col != "country_name"]
for col in numeric_cols:
    ei_crude_cond_production[col] = pd.to_numeric(
        ei_crude_cond_production[col], errors="coerce"
    )

# Drop rows where all values are NA
ei_crude_cond_production = ei_crude_cond_production.dropna(how="all")

# Remove the first two rows and cut off at row 105
ei_crude_cond_production = ei_crude_cond_production.iloc[2:70].copy()

# Reset index after dropping rows
ei_crude_cond_production = ei_crude_cond_production.reset_index(drop=True)
ei_crude_cond_production
# Out:
# Duplicated columns: Index([2023, 2023], dtype='object', name=1)
#                         country_name          2000          2001  \
# 0                             Mexico   3011.965063   3127.036532
# 1                                 US   5821.604000   5801.401000
# 2                Total North America  11029.317934  11150.567354
# 3                          Argentina    775.868527    812.953364
# 4                             Brazil   1235.000000   1297.000000
# ..                               ...           ...           ...
# 63                    of which: OECD  18917.790961  18681.458588
# 64                          Non-OECD  49539.555793  49844.476194
# 65                              OPEC  28049.979511  27604.864850
# 66                         Non-OPEC   40407.367243  40921.069933
# 67                   European Union     819.079158    793.403521
#
#             2002          2003          2004          2005          2006  \
# 0    3177.098964   3370.896011   3382.898325   3333.348751   3255.578844
# 1    5744.078000   5649.300000   5440.968000   5183.822000   5085.864000
# 2   11281.489621  11515.668946  11387.215108  11036.677655  10996.933734
# 3     801.663115    782.814212    733.449060    705.019619    697.917659
# 4    1454.000000   1499.000000   1481.000000   1633.575861   1722.729413
# ..           ...           ...           ...           ...           ...
# 63  18727.482012  18538.695713  18024.608698  17184.501025  16677.125249
# 64  48842.318030  52281.449179  56159.067084  57804.908115  58964.591918
# 65  25648.381541  28003.518431  30772.485034  31648.771478  32162.842299
# 66  41921.418501  42816.626461  43411.190749  43340.637662  43478.874868
# 67    859.485418    856.137281    856.624451    836.321411    775.868136
#
#             2007          2008  ...          2015          2016          2017  \
# 0    3075.709871   2791.575967  ...   2266.831389   2153.526317   1948.263211
# 1    5073.900000   4999.671000  ...   9439.432000   8846.434000   9357.392000
# 2   10899.363484  10506.800578  ...  15569.215279  14868.182651  15521.899256
# 3     689.116081    679.440190  ...    532.438815    510.648772    479.996378
# 4    1747.992319   1812.224569  ...   2437.440349   2509.971215   2621.719965
# ..           ...           ...  ...           ...           ...           ...
# 63  16406.981457  15845.390029  ...  19945.365771  19094.711591  19636.695153
# 64  59049.258018  60182.962770  ...  61742.749216  62466.108986  62171.673168
# 65  31795.054719  32706.999305  ...  32841.342462  33745.620353  33553.366278
# 66  43661.184756  43321.353493  ...  48846.772525  47815.200224  48255.002043
# 67    739.506006    684.105297  ...    522.482882    455.972064    450.106183
#
#             2018          2019          2020          2021          2022  \
# 0    1833.295181   1700.698132   1705.364434   1756.409759   1784.584521
# 1   10951.177000  12311.080000  11318.316000  11267.729000  11910.622000
# 2   17380.913487  18702.190123  17493.735748  17769.343963  18561.654858
# 3     489.833044    607.845184    600.996323    682.225787    831.686662
# 4    2586.623252   2787.757735   2939.950377   2905.120916   3021.504455
# ..           ...           ...           ...           ...           ...
# 63  21497.341444  22853.589355  21708.284075  21810.109519  22436.366503
# 64  62113.641134  60421.087878  55344.705338  56268.879499  58949.128318
# 65  33402.276156  31395.740379  27616.029399  28337.951402  30388.118417
# 66  50208.706422  51878.936854  49436.960015  49741.037616  50997.376405
# 67    435.725904    402.554057    381.978424    359.261642    334.125936
#
#             2023  growth_rate_per_annum_2013_2023
# 0    1875.380805                        -0.029194
# 1   12927.000000                         0.056016
# 2   19737.117600                         0.038685
# 3     946.155559                         0.057698
# 4    3401.622738                         0.053296
# ..           ...                              ...
# 63  23641.627349                         0.029083
# 64  59115.541902                        -0.001456
# 65  29985.249155                        -0.004949
# 66  52771.920097                         0.013342
# 67    316.559458                        -0.053090
#
# [68 rows x 26 columns]

# %%
# Create a unique list of countries from both datasets
countries = pd.DataFrame(
    {
        "country_name": pd.concat(
            [
                ei_crude_cond_production["country_name"],
                ei_oil_consumption["country_name"],
                trade_stag["country_name"],
                trade_optim["country_name"],
                tot_historical["country_name"],
            ]
        ).unique()
    }
)
countries["country_id"] = range(1, len(countries) + 1)

countries
# Out:
#                                           country_name  country_id
# 0                                               Mexico           1
# 1                                                   US           2
# 2                                  Total North America           3
# 3                                            Argentina           4
# 4                                               Brazil           5
# ..                                                 ...         ...
# 159      Countries with predominantly hydro generation         160
# 160     Countries with installed capacity below 200 MW         161
# 161   Countries with installed capacity above 1,000 MW         162
# 162  Countries with installed capacity 200 MW to 1,...         163
# 163    Countries with predominantly thermal generation         164
#
# [164 rows x 2 columns]

# %%
# Step 1: First, merge with the countries table to add country_id
def add_country_ids(df, countries_df):
    # Make sure to retain the original DataFrame columns
    df_with_ids = df.merge(
        countries_df[["country_id", "country_name"]], on="country_name", how="left"
    )
    return df_with_ids


# Let's check the actual column names in your dataframes
print("Production columns:", ei_crude_cond_production.columns.tolist())
print("Countries columns:", countries.columns.tolist())

# Add country_ids to both DataFrames
production_with_ids = add_country_ids(ei_crude_cond_production, countries)
consumption_with_ids = add_country_ids(ei_oil_consumption, countries)

# Now verify that country_id exists in the merged DataFrames
print("Production with IDs columns:", production_with_ids.columns.tolist())

# Step 2: Reshape production data to long format
# Identify year columns (those that are digits)
year_columns_prod = [col for col in production_with_ids.columns if str(col).isdigit()]

# Identify non-year columns to keep as identifiers (exclude country_name as we have country_id now)
id_columns_prod = [
    col
    for col in production_with_ids.columns
    if not str(col).isdigit() and col != "country_name" and col != "country_id"
]

# Now reshape to long format
production_long = pd.melt(
    production_with_ids,
    id_vars=["country_id"]
    + id_columns_prod,  # Include country_id and any other ID columns
    value_vars=year_columns_prod,
    var_name="year",
    value_name="production_barrels",
)

# Convert year to integer type
production_long["year"] = production_long["year"].astype(int)

# Step 3: Reshape consumption data to long format
year_columns_cons = [col for col in consumption_with_ids.columns if str(col).isdigit()]
id_columns_cons = [
    col
    for col in consumption_with_ids.columns
    if not str(col).isdigit() and col != "country_name" and col != "country_id"
]

consumption_long = pd.melt(
    consumption_with_ids,
    id_vars=["country_id"] + id_columns_cons,
    value_vars=year_columns_cons,
    var_name="year",
    value_name="consumption_barrels",
)

# Convert year to integer type
consumption_long["year"] = consumption_long["year"].astype(int)

# Step 4: Clean up the data (handle NaN values, etc.)
production_long = production_long.dropna(subset=["production_barrels"])
consumption_long = consumption_long.dropna(subset=["consumption_barrels"])

# Print the first few rows of each to verify
print("\nProduction Long Format (first 5 rows):")
print(production_long.head())

print("\nConsumption Long Format (first 5 rows):")
print(consumption_long.head())
# Out:
# Production columns: ['country_name', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', 'growth_rate_per_annum_2013_2023']
# Countries columns: ['country_name', 'country_id']
# Production with IDs columns: ['country_name', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', 'growth_rate_per_annum_2013_2023', 'country_id']
#
# Production Long Format (first 5 rows):
#    country_id  growth_rate_per_annum_2013_2023  year  production_barrels
# 0           1                        -0.029194  2000         3011.965063
# 1           2                         0.056016  2000         5821.604000
# 2           3                         0.038685  2000        11029.317934
# 3           4                         0.057698  2000          775.868527
# 4           5                         0.053296  2000         1235.000000
#
# Consumption Long Format (first 5 rows):
#    country_id  growth_rate_per_annum_2013_2023  year  consumption_barrels
# 0           1                        -0.009963  1965           315.871088
# 1           2                         0.005379  1965         11512.436000
# 2           3                         0.003158  1965         12936.423389
# 3           4                         0.000639  1965           455.874013
# 4           5                        -0.003217  1965           305.673808

# %% [markdown]
# #### Write to csv

# %%
production_long.to_csv(
    os.path.join("energy_data", "ei_oil_production.csv"), index=False, sep=","
)
consumption_long.to_csv(
    os.path.join("energy_data", "ei_oil_consumption.csv"), index=False, sep=","
)
countries.to_csv(os.path.join("energy_data", "countries.csv"), index=False, sep=",")

# %% [markdown]
# ###
